# %% [markdown]
# ## Installing Firebase SDK
# Our data comes from firebase so we install the firebase SDK to access it.

# %%
# !pip install firebase-admin
# Out:
# Collecting firebase-admin
#   Downloading https://files.pythonhosted.org/packages/a9/89/c85e7ffbebda6df99080be8180d6e37f0db2b5c6857af5e608078b8374c2/firebase_admin-2.16.0-py2.py3-none-any.whl (92kB)
#     100% |████████████████████████████████| 102kB 187kB/s a 0:00:01
# Collecting cachecontrol>=0.12.4 (from firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/5e/f0/2c193ed1f17c97ae539da7e1c2d48b80d8cccb1917163b26a91ca4355aa6/CacheControl-0.12.5.tar.gz
# Collecting google-api-core[grpc]<2.0.0dev,>=1.7.0; platform_python_implementation != "PyPy" (from firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/55/8d/02cd1468659994a39b1aced38fecb06885c988d79aaafd8d456d09571871/google_api_core-1.8.0-py2.py3-none-any.whl (65kB)
#     100% |████████████████████████████████| 71kB 278kB/s ta 0:00:011
# Collecting google-cloud-firestore>=0.31.0; platform_python_implementation != "PyPy" (from firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/58/0d/60b5f96aca1b88a7555f2758cae3a19956b9cdb65e562f5313224642783e/google_cloud_firestore-0.31.0-py2.py3-none-any.whl (125kB)
#     100% |████████████████████████████████| 133kB 204kB/s ta 0:00:01
# Collecting google-cloud-storage>=1.13.0 (from firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/b6/e9/06d9bb394fddbc62bb9c645f5e1c927128930a249d0c6a7491c3f31a9ff4/google_cloud_storage-1.14.0-py2.py3-none-any.whl (60kB)
#     100% |████████████████████████████████| 61kB 103kB/s a 0:00:0111
# Requirement already satisfied: six>=1.6.1 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from firebase-admin) (1.11.0)
# Collecting requests (from cachecontrol>=0.12.4->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/7d/e3/20f3d364d6c8e5d2353c72a67778eb189176f08e873c9900e10c0287b84b/requests-2.21.0-py2.py3-none-any.whl (57kB)
#     100% |████████████████████████████████| 61kB 157kB/s ta 0:00:01
# Collecting msgpack (from cachecontrol>=0.12.4->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/81/9c/0036c66234482044070836cc622266839e2412f8108849ab0bfdeaab8578/msgpack-0.6.1.tar.gz (118kB)
#     100% |████████████████████████████████| 122kB 334kB/s ta 0:00:01
# Collecting googleapis-common-protos!=1.5.4,<2.0dev,>=1.5.3 (from google-api-core[grpc]<2.0.0dev,>=1.7.0; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/21/fd/0ea06fab3651857955f2240a20cf951a29c1cdfdc937c3d19d8575651a64/googleapis-common-protos-1.5.8.tar.gz
# Collecting google-auth<2.0dev,>=0.4.0 (from google-api-core[grpc]<2.0.0dev,>=1.7.0; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/c5/9b/ed0516cc1f7609fb0217e3057ff4f0f9f3e3ce79a369c6af4a6c5ca25664/google_auth-1.6.3-py2.py3-none-any.whl (73kB)
#     100% |████████████████████████████████| 81kB 398kB/s ta 0:00:011
# Requirement already satisfied: pytz in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.7.0; platform_python_implementation != "PyPy"->firebase-admin) (2018.9)
# Requirement already satisfied: setuptools>=34.0.0 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.7.0; platform_python_implementation != "PyPy"->firebase-admin) (39.0.1)
# Collecting protobuf>=3.4.0 (from google-api-core[grpc]<2.0.0dev,>=1.7.0; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/e3/4b/46c4d78596f86aa07143328fd7ffbe3aabf61d47ee25337b7b173149bbdc/protobuf-3.7.0-cp36-cp36m-macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (1.3MB)
#     100% |████████████████████████████████| 1.3MB 404kB/s ta 0:00:01
# Collecting grpcio>=1.8.2; extra == "grpc" (from google-api-core[grpc]<2.0.0dev,>=1.7.0; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/b1/45/0ae182eb92a516a2485e803236eaa90b99d17fea0b3e32d891ce5d33893a/grpcio-1.19.0-cp36-cp36m-macosx_10_9_x86_64.whl (1.8MB)
#     100% |████████████████████████████████| 1.8MB 746kB/s ta 0:00:01
# Collecting google-cloud-core<0.30dev,>=0.29.0 (from google-cloud-firestore>=0.31.0; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/0c/f2/3c225e7a69cb27d283b68bff867722bd066bc1858611180197f711815ea5/google_cloud_core-0.29.1-py2.py3-none-any.whl
# Collecting google-resumable-media>=0.3.1 (from google-cloud-storage>=1.13.0->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/e2/5d/4bc5c28c252a62efe69ed1a1561da92bd5af8eca0cdcdf8e60354fae9b29/google_resumable_media-0.3.2-py2.py3-none-any.whl
# Collecting urllib3<1.25,>=1.21.1 (from requests->cachecontrol>=0.12.4->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/62/00/ee1d7de624db8ba7090d1226aebefab96a2c71cd5cfa7629d6ad3f61b79e/urllib3-1.24.1-py2.py3-none-any.whl (118kB)
#     100% |████████████████████████████████| 122kB 959kB/s ta 0:00:01
# Collecting certifi>=2017.4.17 (from requests->cachecontrol>=0.12.4->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/9f/e0/accfc1b56b57e9750eba272e24c4dddeac86852c2bebd1236674d7887e8a/certifi-2018.11.29-py2.py3-none-any.whl (154kB)
#     100% |████████████████████████████████| 163kB 951kB/s ta 0:00:01
# Collecting chardet<3.1.0,>=3.0.2 (from requests->cachecontrol>=0.12.4->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
#     100% |████████████████████████████████| 143kB 998kB/s ta 0:00:01
# Collecting idna<2.9,>=2.5 (from requests->cachecontrol>=0.12.4->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#     100% |████████████████████████████████| 61kB 245kB/s ta 0:00:01
# Collecting pyasn1-modules>=0.2.1 (from google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.7.0; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/da/98/8ddd9fa4d84065926832bcf2255a2b69f1d03330aa4d1c49cc7317ac888e/pyasn1_modules-0.2.4-py2.py3-none-any.whl (66kB)
#     100% |████████████████████████████████| 71kB 637kB/s ta 0:00:011
# Collecting rsa>=3.1.4 (from google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.7.0; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/02/e5/38518af393f7c214357079ce67a317307936896e961e35450b70fad2a9cf/rsa-4.0-py2.py3-none-any.whl
# Collecting cachetools>=2.0.0 (from google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.7.0; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/39/2b/d87fc2369242bd743883232c463f28205902b8579cb68dcf5b11eee1652f/cachetools-3.1.0-py2.py3-none-any.whl
# Collecting pyasn1<0.5.0,>=0.4.1 (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.7.0; platform_python_implementation != "PyPy"->firebase-admin)
#   Downloading https://files.pythonhosted.org/packages/7b/7c/c9386b82a25115cccf1903441bba3cbadcfae7b678a20167347fa8ded34c/pyasn1-0.4.5-py2.py3-none-any.whl (73kB)
#     100% |████████████████████████████████| 81kB 526kB/s ta 0:00:011
# Installing collected packages: urllib3, certifi, chardet, idna, requests, msgpack, cachecontrol, protobuf, googleapis-common-protos, pyasn1, pyasn1-modules, rsa, cachetools, google-auth, grpcio, google-api-core, google-cloud-core, google-cloud-firestore, google-resumable-media, google-cloud-storage, firebase-admin
#   Running setup.py install for msgpack ... done
#   Running setup.py install for cachecontrol ... done
#   Running setup.py install for googleapis-common-protos ... done
# Successfully installed cachecontrol-0.12.5 cachetools-3.1.0 certifi-2018.11.29 chardet-3.0.4 firebase-admin-2.16.0 google-api-core-1.8.0 google-auth-1.6.3 google-cloud-core-0.29.1 google-cloud-firestore-0.31.0 google-cloud-storage-1.14.0 google-resumable-media-0.3.2 googleapis-common-protos-1.5.8 grpcio-1.19.0 idna-2.8 msgpack-0.6.1 protobuf-3.7.0 pyasn1-0.4.5 pyasn1-modules-0.2.4 requests-2.21.0 rsa-4.0 urllib3-1.24.1
# You are using pip version 19.0.2, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# # Inputs and Features
#
# As an input, our model will receive a json file with all the emails labeled and will pass as a dataframe. The features in our dataset are the language of the email, the type, the majors that applies to the email & the audience that applies.
#
# The labels in our datasets are:
#
# **Internship or Job Application** - Applies to internships opportunities from companies & job applications from the university.
#
# **Scholarships & Fellowship** - Applies scholarships opportunity for all the students & Fellowships from a variety of organizations.
#
# **Volunteer** - Volunteering experience for all the students.
#
# **Sports & Fitness** - A variety of opportunities to be part of a sport team of the university of be part of a class to do a variety of exercises.
#
# **Workshops** - Opportunities of a variety of workshops or
#
# **Class** - Any announcement regarding to a class of the university.
#
# **Competition** - Opportunities of competitions for the students.
#
# **Conference** - A variety of talks, conferences from a faculty member of the university or from a company.
#
# **Social Events** - An event for everybody to join.
#
# **Sale** - Any sale made within the university.
#
# **Research** - Any research opportunity for the students or announcement from the researches within the university.
#
# **Health & Security** - Announcements to do exercises like zumba & dancing.
#
# **Students Associations** - Any announcement regarding to the student associations from the university.
#
# **University Announcements** - Any announcement from the university.
#
# **Other** - Any other email that can not be categorized from the previous labels.
#
# **Spanish**
#
# **English**
#
# **Engineering**
#
# **Arts & Science**
#
# **Business**
#
# **Agriculture**
#
# **All Majors**
#
# **Undergradute Students**
#
# **Graduate Students**
#
# **Faculty**
#
# **All Students**
#
# **Everyone**

# %% [markdown]
# ## Using Keras to build neural network
# Reference: https://www.tensorflow.org/guide/keras#train_and_evaluate
#
# Reference 2: https://github.com/tensorflow/workshops/blob/master/extras/keras-bag-of-words/keras-bow-model.ipynb

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading https://files.pythonhosted.org/packages/f6/7b/5ab19bac13810661ff9e2485811553f1dea9a5d611ce846345aed4766bbe/tensorflow-1.13.1-cp36-cp36m-macosx_10_11_x86_64.whl (71.6MB)
#     100% |████████████████████████████████| 71.6MB 226kB/s ta 0:00:01   10% |███▍                            | 7.6MB 293kB/s eta 0:03:38    21% |███████                         | 15.7MB 584kB/s eta 0:01:36    31% |██████████▏                     | 22.7MB 817kB/s eta 0:01:00    77% |████████████████████████▉       | 55.6MB 240kB/s eta 0:01:07    79% |█████████████████████████▍      | 56.9MB 346kB/s eta 0:00:43    83% |██████████████████████████▋     | 59.6MB 246kB/s eta 0:00:49
# Collecting tensorboard<1.14.0,>=1.13.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/fa/7b/3ee06856ec30d5136cd2002408df1d111fcff269f3691147dbf3b8dc0ba2/tensorboard-1.13.0-py3-none-any.whl (3.2MB)
#     100% |████████████████████████████████| 3.2MB 344kB/s ta 0:00:01    33% |██████████▋                     | 1.1MB 447kB/s eta 0:00:05    56% |██████████████████              | 1.8MB 432kB/s eta 0:00:04
# Collecting absl-py>=0.1.6 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/31/bc/ab68120d1d89ae23b694a55fe2aece2f91194313b71f9b05a80b32d3c24b/absl-py-0.7.0.tar.gz (96kB)
#     100% |████████████████████████████████| 102kB 361kB/s a 0:00:01
# Requirement already satisfied: numpy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from tensorflow) (1.16.1)
# Requirement already satisfied: six>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from tensorflow) (1.11.0)
# Collecting wheel>=0.26 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/96/ba/a4702cbb6a3a485239fbe9525443446203f00771af9ac000fa3ef2788201/wheel-0.33.1-py2.py3-none-any.whl
# Collecting astor>=0.6.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/35/6b/11530768cac581a12952a2aad00e1526b89d242d0b9f59534ef6e6a1752f/astor-0.7.1-py2.py3-none-any.whl
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/bb/48/13f49fc3fa0fdf916aa1419013bb8f2ad09674c275b4046d5ee669a46873/tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367kB)
#     100% |████████████████████████████████| 368kB 201kB/s ta 0:00:01
# Collecting gast>=0.2.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting keras-preprocessing>=1.0.5 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/c0/bf/0315ef6a9fd3fc2346e85b0ff1f5f83ca17073f2c31ac719ab2e4da0d4a3/Keras_Preprocessing-1.0.9-py2.py3-none-any.whl (59kB)
#     100% |████████████████████████████████| 61kB 224kB/s ta 0:00:01
# Requirement already satisfied: protobuf>=3.6.1 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from tensorflow) (3.7.0)
# Collecting keras-applications>=1.0.6 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/90/85/64c82949765cfb246bbdaf5aca2d55f400f792655927a017710a78445def/Keras_Applications-1.0.7-py2.py3-none-any.whl (51kB)
#     100% |████████████████████████████████| 61kB 398kB/s ta 0:00:011
# Requirement already satisfied: grpcio>=1.8.6 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from tensorflow) (1.19.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow) (0.14.1)
# Collecting markdown>=2.6.8 (from tensorboard<1.14.0,>=1.13.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/7a/6b/5600647404ba15545ec37d2f7f58844d690baf2f81f3a60b862e48f29287/Markdown-3.0.1-py2.py3-none-any.whl (89kB)
#     100% |████████████████████████████████| 92kB 352kB/s ta 0:00:011
# Collecting mock>=2.0.0 (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/e6/35/f187bdf23be87092bd0f1200d43d23076cee4d0dec109f195173fd3ebc79/mock-2.0.0-py2.py3-none-any.whl (56kB)
#     100% |████████████████████████████████| 61kB 379kB/s ta 0:00:01
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from protobuf>=3.6.1->tensorflow) (39.0.1)
# Collecting h5py (from keras-applications>=1.0.6->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/03/21/1cdf7fa7868528b35c1a08a770eb9334279574a8b5f1d7a2966dcec14e42/h5py-2.9.0-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (6.3MB)
#     100% |████████████████████████████████| 6.3MB 562kB/s ta 0:00:01
# Collecting pbr>=0.11 (from mock>=2.0.0->tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/14/09/12fe9a14237a6b7e0ba3a8d6fcf254bf4b10ec56a0185f73d651145e9222/pbr-5.1.3-py2.py3-none-any.whl (107kB)
#     100% |████████████████████████████████| 112kB 637kB/s ta 0:00:01
# Installing collected packages: wheel, markdown, absl-py, tensorboard, astor, pbr, mock, tensorflow-estimator, gast, termcolor, keras-preprocessing, h5py, keras-applications, tensorflow
#   Running setup.py install for absl-py ... done
#   Running setup.py install for gast ... done
#   Running setup.py install for termcolor ... done
# Successfully installed absl-py-0.7.0 astor-0.7.1 gast-0.2.2 h5py-2.9.0 keras-applications-1.0.7 keras-preprocessing-1.0.9 markdown-3.0.1 mock-2.0.0 pbr-5.1.3 tensorboard-1.13.0 tensorflow-1.13.1 tensorflow-estimator-1.13.0 termcolor-1.1.0 wheel-0.33.1
# You are using pip version 19.0.2, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install keras
# Out:
# Collecting keras
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#     100% |████████████████████████████████| 317kB 537kB/s ta 0:00:01
# Requirement already satisfied: scipy>=0.14 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from keras) (1.2.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from keras) (1.0.9)
# Requirement already satisfied: six>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from keras) (1.11.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from keras) (1.0.7)
# Collecting pyyaml (from keras)
#   Downloading https://files.pythonhosted.org/packages/9e/a3/1d13970c3f36777c583f136c136f804d70f500168edc1edea6daa7200769/PyYAML-3.13.tar.gz (270kB)
#     100% |████████████████████████████████| 276kB 601kB/s ta 0:00:01
# Requirement already satisfied: h5py in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from keras) (2.9.0)
# Requirement already satisfied: numpy>=1.9.1 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from keras) (1.16.1)
# Building wheels for collected packages: pyyaml
#   Building wheel for pyyaml (setup.py) ... done
#   Stored in directory: /Users/fernandorodriguez/Library/Caches/pip/wheels/ad/da/0c/74eb680767247273e2cf2723482cb9c924fe70af57c334513f
# Successfully built pyyaml
# Installing collected packages: pyyaml, keras
# Successfully installed keras-2.2.4 pyyaml-3.13
# You are using pip version 19.0.2, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from keras.preprocessing import text, sequence
from keras import utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from sklearn.preprocessing import MultiLabelBinarizer, LabelEncoder
from sklearn.metrics import confusion_matrix
from keras import regularizers
from keras import metrics
import pandas as pd
import numpy as np
import math
import re
import json
from firebase_admin import db, credentials
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_rows = 15
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## Firebase Admin SDK credentials
# Our service account file is in our google drive so we import it from google drive by mounting the google drive into the colab.

# %%
import firebase_admin
if (not len(firebase_admin._apps)):
    cred = credentials.Certificate('./easy-cartero-firebase-adminsdk-1sp67-ffb2ac83bf.json') 
    default_app = firebase_admin.initialize_app(cred, {'databaseURL': 'https://easy-cartero.firebaseio.com/'})

# %%
# Get a database reference to our posts
ref = db.reference();
ref = ref.child('Production/labeled')
data = ref.get()

#convert dictionary into array of items
emails = json.dumps(list(data.values()))
df = pd.read_json(emails)
df.describe()
#We have the first 162 emails with NaN so we replace with default value
for index in range(0,163):
  df['audience'][index] = ['Everyone']

# %%
#Cleans up the body of the email by removing punctuation
def sanitize_features(df):
  """
  This function will replace urls with ' LINK '. It
  also makes label column to collect all labels into 
  one column.
  """
  print('Cleaning Data...')
  df['labels'] = [[] for _ in range(len(df))]
  #df['encoded_labels'] = [[] for _ in range(len(df))]
  for index in range(0, df['body'].size):
    df['body'][index] = re.sub(r'^https?:\/\/.*[\r\n]*', ' LINK ', str(df['body'][index]), flags=re.MULTILINE).lower()
    labels = []
    labels.extend(df['audience'][index])
    labels.extend(df['emailType'][index])
    labels.extend(df['majors'][index])
    labels.append(df['language'][index])
    df['labels'][index] = labels
  print('Finished Clearning!')

# %%
##clean data and remove unnecessary columns
sanitize_features(df)
df.drop(columns=['audience','author', 'date', 'emailType', 'key', 'language', 'majors', 'subject'])
# Out:
# Cleaning Data...
# Finished Clearning!
#                                                    body  \
# 0     ¡saludos, colegiales!\r\r\n\r\r\n\r\r\nel depa...
# 1     ¡saludos, colegiales!\r\r\n\r\r\n¿te has pregu...
# 2     el comité de búsqueda y consulta del senado ac...
# 3     ¡saludos, colegiales y comunidad en general!\r...
# 4     el comite de búsqueda y consulta para el nombr...
# 5     estimada comunidad universitaria,\r\r\n\r\r\nl...
# 6     ¡¡saludos colegiales!!\r\r\n\r\r\nven, anímate...
# ...                                                 ...
# 1394  faltan 32 días para el evento por la vida y el...
# 1395  saludos colegiales,\r\r\n\r\r\ncover letters a...
# 1396  saludos colegiales,\r\r\n\r\r\ncover letters a...
# 1397  por este medio les invitamos a la charla \r\r\...
# 1398  estudiantes de inme, inin y kine interesados e...
# 1399  greetings colegiales!\r\r\n\r\r\n\r\r\n\r\r\n\...
# 1400  la división de educación continua y estudios p...
#
#                                                  labels
# 0     [Everyone, University Announcement, Arts & Sci...
# 1           [Everyone, Class, Arts & Sciences, Spanish]
# 2     [Everyone, Competition, University Announcemen...
# 3     [Everyone, Sports & Fitness, Class, All Majors...
# 4     [Everyone, Competition, University Announcemen...
# 5            [Everyone, Competition, Business, Spanish]
# 6     [Everyone, Sports & Fitness, Class, All Majors...
# ...                                                 ...
# 1394  [Everyone, Volunteer, University Announcement,...
# 1395  [Undergraduate Student, Graduate Student, Work...
# 1396  [Everyone, Workshop, Sale, Student Association...
# 1397        [Everyone, Conference, All Majors, Spanish]
# 1398  [Undergraduate Student, Student Associations, ...
# 1399  [All Students, Internship or Job Application, ...
# 1400  [All Students, Class, University Announcement,...
#
# [1401 rows x 2 columns]

# %%
possible_labels = ['Internship or Job Application','Scholarships & Fellowship','Volunteer','Sports & Fitness','Workshop','Class',
                    'Competition','Conference','Social Events','Sale','Research','Health & Security','Student Associations',
                    'University Announcement', 'Other','Spanish','English','Engineering','Arts & Sciences','Business','Agriculture',
                    'All Majors','Undergraduate Student','Graduate Student','Faculty','All Students','Everyone']

## shuffle data
df.reindex(np.random.permutation(df.index))
#define training data size
train_data_ratio = 1.0
training_size = int(len(df) * train_data_ratio)

#split data into training and validation data
training_emails = df['body'][:training_size]
training_labels = df['labels'][:training_size]

validation_emails = df['body'][:training_size]
validation_labels = df['labels'][:training_size]

from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
vectorizer.fit_transform(df['body']).todense()

vocabulary_size = len(vectorizer.vocabulary_) 
tokenize = text.Tokenizer(num_words=vocabulary_size, char_level=False, lower=False, split=' ')

tokenize.fit_on_texts(training_emails) # only fit on train
tokenized_emails_train = tokenize.texts_to_matrix(training_emails)
tokenized_emails_validation = tokenize.texts_to_matrix(validation_emails)

# Use sklearn utility to convert label strings to numbered index
encoder = MultiLabelBinarizer(classes= possible_labels)
encoder.fit(df['labels'])
encoded_training = encoder.transform(training_labels)
encoded_validation = encoder.transform(validation_labels)
num_classes = len(possible_labels)

print('tokenized_emails_train shape:', tokenized_emails_train.shape)
print('tokenized_emails_validation shape:', validation_emails.shape)
print('encoded_training shape:', encoded_training.shape)
print('encoded_validation shape:', encoded_validation.shape)
# Out:
# tokenized_emails_train shape: (1401, 13395)
# tokenized_emails_validation shape: (1401,)
# encoded_training shape: (1401, 27)
# encoded_validation shape: (1401, 27)

# %%
def build_model(l1_reg, l2_reg, learning_rate, vocabulary_size, num_classes):
  model = Sequential([
    Dense(2048, input_shape = (vocabulary_size,), activation = 'relu', kernel_regularizer=regularizers.l2(l2_reg), activity_regularizer=regularizers.l1(l1_reg)),
    Dense(1024, activation = 'relu', kernel_regularizer=regularizers.l2(l2_reg), activity_regularizer=regularizers.l1(l1_reg)),
    Dense(num_classes, activation='sigmoid')
  ])
  model.compile(optimizer = tf.train.AdamOptimizer(learning_rate),
                loss ='binary_crossentropy',
                metrics = [metrics.binary_accuracy])
  return model

# %% [markdown]
# # Training Our Model

# %%
def train_model(model, tokenized_emails_train, encoded_label_training, tokenized_emails_validation, encoded__label_validation, batch_size = 150, steps = 100, epochs = 5, verbose = 1, validation_split = 0.5):
  train = model.fit(tokenized_emails_train, encoded_training,
                    batch_size= batch_size, 
                    epochs= epochs, 
                    verbose= verbose,
                    validation_split= validation_split)
  evaluation = model.evaluate(tokenized_emails_validation,
                            encoded__label_validation, 
                            batch_size= batch_size, 
                            verbose= verbose)
  print('Test score:', evaluation[0])
  print('Test accuracy:', evaluation[1])
  print (evaluation)
  return train

batch_size = 100
steps = 75
epochs = 5
verbose = 1
validation_split = 0.4
L1_regularization = 0.0000025
L2_regularization = 0.00000025
LEARNING_RATE = 0.001
Positive_Label_Threshold = 0.5

model = build_model(
  l1_reg = L1_regularization,
  l2_reg = L2_regularization, 
  learning_rate = LEARNING_RATE,
  vocabulary_size = len(vectorizer.vocabulary_),
  num_classes = num_classes
)

history = train_model(
  model = model,
  tokenized_emails_train = tokenized_emails_train,
  encoded_label_training = encoded_training,
  tokenized_emails_validation = tokenized_emails_validation,
  encoded__label_validation = encoded_validation,
  batch_size = batch_size,
  steps = steps,
  epochs = epochs,
  verbose = verbose,
  validation_split = validation_split
)
# Out:
# Train on 840 samples, validate on 561 samples
# Epoch 1/5
# 840/840 [==============================] - 6s 7ms/step - loss: 0.5007 - binary_accuracy: 0.8118 - val_loss: 0.4221 - val_binary_accuracy: 0.8775
# Epoch 2/5
# 840/840 [==============================] - 3s 4ms/step - loss: 0.3412 - binary_accuracy: 0.8974 - val_loss: 0.3684 - val_binary_accuracy: 0.8813
# Epoch 3/5
# 840/840 [==============================] - 3s 4ms/step - loss: 0.2655 - binary_accuracy: 0.9293 - val_loss: 0.3707 - val_binary_accuracy: 0.8844
# Epoch 4/5
# 840/840 [==============================] - 3s 4ms/step - loss: 0.2137 - binary_accuracy: 0.9524 - val_loss: 0.3632 - val_binary_accuracy: 0.8860
# Epoch 5/5
# 840/840 [==============================] - 3s 3ms/step - loss: 0.1804 - binary_accuracy: 0.9646 - val_loss: 0.3678 - val_binary_accuracy: 0.8826
# 1401/1401 [==============================] - 2s 1ms/step
# Test score: 0.24593562181297154
# Test accuracy: 0.9368705020726876
# [0.24593562181297154, 0.9368705020726876]

# %% [markdown]
# Reference: https://machinelearningmastery.com/display-deep-learning-model-training-history-in-keras/

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
 
def plot_history(history):
    keys = history.history.keys()
    # eprint(keys)
    for key in filter(lambda k:"val_" not in k,  keys):   
        plt.plot(history.history[key])
        plt.plot(history.history['val_'+key ])
        plt.title( key)
        plt.ylabel('key')
        plt.xlabel('epoch')
        plt.legend(['train', 'validation'], loc='upper right')
        plt.show()

# %%
plot_history(history)

# %% [markdown]
# ## Metrics & testing

# %%
def make_roc_curve(predictions, targets, possible_labels):
  """ Plots an ROC curve for the provided predictions and targets.

  Args:
    predictions: the probability that the example has label 1.
    targets: a list of the target values being predicted that must be the
             same length as predictions.
  """
  for i in range(len(possible_labels)):
    false_positive_rate, true_positive_rate, thresholds = metrics.roc_curve(
      [row[i] for row in targets], [row[i] for row in predictions])
    plt.subplot(5,6,i+1, title= possible_labels[i])
    plt.plot(false_positive_rate, true_positive_rate)
    plt.ylabel("true positive rate")
    plt.xlabel("false positive rate")
  plt.show()

# %%
from sklearn import metrics
predictions = model.predict(tokenized_emails_train)
fig = plt.gcf()
fig.set_size_inches(20, 20, forward=True)
make_roc_curve(predictions, encoded_training, possible_labels)

# %%
text = "The Industrial Engineering Honor Society Alpha Pi Mu invites you to collaborate in our School Supplies Drive Supplies will be donated to students with special education needs from Elpidio H Rivera School in Mayag\xFCez We will be collecting items until December 3rd in II 101 You can also contact our Community Service Director Cristina Qui\xF1ones at\xA0LINK for the delivery of items and more information The items being collected are pencils crayons construction paper copy paper erasers rulers scissors glue markers disinfecting wipes baby wipes paper towels You can also donate money for the purchase of school supplies through ATH M\xF3vil to the number 787 410 8314 Please send it with the message supply so we know the money is for cooperating with the cause Giving is not just about making a donation It is about making a difference Kathy Calvin Thank you" #@param {type:"string"}

# %%
def extract_labels_from_prediction(possible_labels, prediction, threshold):
  labels = []
  for index in range(0, len(possible_labels)):
    if(prediction[index] >= threshold):
      labels.append(possible_labels[index])
  return labels

# %%
for i in range(0, len(predictions)):
  predicted_label = extract_labels_from_prediction(encoder.classes_, predictions[i], Positive_Label_Threshold)
  actual_labels = extract_labels_from_prediction(encoder.classes_, encoded_training[i], Positive_Label_Threshold)
  print(training_emails[i])
  print("Predicted labels: " + str(predicted_label) + "\n")
  print("Actual labels: " + str(actual_labels) + "\n")
# Out:
# ¡saludos, colegiales!
#
#
# el departamento de humanidades, con motivo del día mundial de la filosofía, te invita al cine-foro: “ghost in the shell: filosofía y cyberpunk”. el mismo se celebrará el próximo jueves, 15 de noviembre a las 6:00 pm. en ch-228.
#
# "ghost in the shell" es una película de ciencia ficción de anime aclamada por la crítica, basada en el popular manga de masamune shirow que lleva el mismo nombre. la película—considerada una de las mejores en su género—fue dirigida por mamoru oshii y se estrenó en 1995. entre los temas que explora se encuentran la identidad, la evolución y la religión.
#
# la historia gira en torno a una agente de seguridad pública que persigue a un hacker misterioso conocido como ‘puppet master’. durante la misión, la protagonista se enfrenta a infinidad de problemas, así como a una lucha con su propia identidad.
#
# algunos de los temas en los que estarán trabajando nuestros panelistas serán “los aspectos de género en la narrativa cyborg” (camila seda), “el ritual del signo y sujeto político en el cyberpunk” (axel bermúdez) y “onlife: la vida online, o ¿cómo la información nos constituye como persona?” (marcel morales).
#
# ¡anímate!
#
# ----
# para más detalles, pueden contactar a la dra. iliaris avilés (iliaris.aviles@upr.edu) o al departamento de humanidades a través de su correo electrónico huma@uprm.edu .
#
# Predicted labels: ['University Announcement', 'Spanish', 'Arts & Sciences', 'Everyone']
#
# Actual labels: ['University Announcement', 'Spanish', 'Arts & Sciences', 'Everyone']
#
# ¡saludos, colegiales!
#
# ¿te has preguntado sobre el origen de las cosas? ¿de dónde viene el universo? ¿por qué el mundo es precisamente este y no otro? ¿existe dios? ¿qué es el ser humano? ¿qué es lo bello y lo justo? ¿quién eres?
#
# el departamento de humanidades, con motivo del día mundial de la filosofía, te presenta una alternativa para encaminarte hacia la búsqueda de las respuestas que buscas en la conferencia “una vez más, ¿qué es la filosofía?” a cargo del dr. francisco josé ramos.
#
# fecha: jueves, 15 de noviembre de 2018
# lugar: ch-228
# hora: 10:30-11:45 a.m. (hora universal)
#
# el doctor ramos es profesor jubilado del programa de filosofía del recinto de río piedras y una de las figuras más queridas y distinguidas de la disciplina en el ámbito local. igualmente, es miembro fundador de la sociedad puertorriqueña de filosofía, así como miembro numerario de la academia puertorriqueña de la lengua española. ha sido profesor e investigador visitante en distintos centros docentes alrededor del mundo y colaborador activo en la revista digital 80 grados.
#
# ¡te esperamos!
#
# ----
# para más detalles, pueden contactar a la dra. iliaris avilés (iliaris.aviles@upr.edu) o al departamento de humanidades a través de su correo electrónico huma@uprm.edu .
#
# Predicted labels: ['Class', 'Spanish', 'Arts & Sciences', 'Everyone']
#
# Actual labels: ['Class', 'Spanish', 'Arts & Sciences', 'Everyone']
#
# el comité de búsqueda y consulta del senado académico del recinto universitario de mayagüez, para el nombramiento del décimocuarto rector(a) del rum anuncia a la comunidad universitaria las próximas actividades.  invitamos a todos a participar de las mismas.
#
# 14 de octubre - 16 de noviembre de 2018 (4:30 pm)
# período para recibir nominacikones de candidatos por parte de la comunidad universitaria o auto nominaciones.  se requiere carta de nominación con razones por las cuales se entiende que el candidato sería un buen rector para el rum.
#
# 30 de octubre de 2018 (10:30 am - 12:00 md)
# en el salon 242 del edificio lucchetti (ingeniería mecánica), vista pública para recopilar opiniones sobre las prioridades institucionales que deberá atender el nuevo rector o rectora y/o nominación de candidatos.
#
# 1 de noviembre de 2018 (10:30 am - 12:00 md)
# en el salón 206 del edificio piñero (ciencias agrícolas)
# vista pública para recopilar opiniones sobre las prioridades institucionales que deberá atender el nuevo rector o rectora y/o nominación de candidatos.
#
# 13 y 15 de noviembre (4:30 pm - 6:00 pm) en la sala de reuniones del senado académico (edificio musa).
# vistas públicas para recibir nominación de candidatos o insumo de candidatos ya sometidos.
#
# 27 de noviembre (10:30 am - 12:00 md) en el salón 341 de administración de empresas, vistas públicas para recibir comentarios sobre los candidatos ya presentados.
#
# 29 de noviembre (10:30 am - 12:00 md) en celis 202, vistas públicas para recibir comentarios sobre los candidatos ya presentados.
#
# 3 de diciembre (5:00 pm)  foro para la presentación de candidatos a rector del rum.  de ser necesario se realizará una segunda parte el 4 de diciembre, pendendiendo del número de candidatos totales.  en el anfiteatro de administración de empresas.
#
# el comité estará realizando seis (6) vistas públicas para recibir información o aportaciones de la comunidad universitaria en las fechas antes mencionadas, el lugar o lugares en el rum será anunciado próximamente.
# el periodo para someter nominaciones cierra el 16 de noviembre de 2018, a las 4:30 de la tarde.
#
# tanto las ponencias como las nominaciones pueden ser enviadas vía electrónica a:
#     consulta.rector@uprm.edu
# o en un sobre sellado a la siguiente dirección:
#    comité de búsqueda y consulta
#    recinto universitario de mayagüez
#    senado académico
#    p o box 9000
#    mayagüez  pr  00681-9000
#
#
#
#
# nota:  al personal de cti,  necesitamos que esta información se envíe por cartero el lunes y miercoles, por favor.   gracias.
#
# Predicted labels: ['Competition', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Competition', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# ¡saludos, colegiales y comunidad en general!
#
# el complejo natatorio, tenis y racquetball se complace en presentar su curso de cpr/dea/primeros auxilios.
#
# costo: $60.00
#
# tiempo de del curso
# 8:00am-5:00pm
#
# la certificación es por la cruz roja americana
#
# **para organizaciones, asociaciones, agencias de gobierno y otras entidades por acuerdo**
# dudas o cualquier otra información, comunícate con nosotros al 787-832-4040; ext. 5777 y 6257 o escríbenos a natatorio@uprm.edu
#
# Predicted labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# el comite de búsqueda y consulta para el nombramiento del rector(a) del rum informa las siguientes fechas importantes:
#
# 24 de octubre al 16 de noviembre de 2018 a las 4:30 pm
# período para recibir nominaciones de candidatos por parte de la comunidad universitaria o auto nominaciones.  se requiere carta de nominación con razones por las cuales entiende que el candidato sería un buen rector para el rum.
#
# 30 de octubre (10:30 am. a 12:00 md) en el salón 242 del edificio lucchetti (ing. mecánica), vista publica para recopilar opiniones sobre las prioridades institucionales que deberá atender el nuevo rector o rectora y/o nominación de candidatos.
#
# 1 de noviembre (10:30 am. a 12 md) en el salón 206 del edificio piñero (ciencias agrícolas), vista pública para recopilar opiniones sobre las prioridades institucionales que deberá atender el nuevo rector o rectora y/o nominación de candidatos.
#
# Predicted labels: ['University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Competition', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# estimada comunidad universitaria,
#
# la asociación estudiantil de profesionales administrativos mejor conocida como aepa invitan a todos los estudiantes de adof y socios de aepa a participar en la competencia de cotejo de documentos y de teclado a nivel intermedio.  la misma se llevará a cabo el martes, 30 de octubre de 2018 en el salón ae-102, a la hora universal (10:30am).
#
# se otorgará un premio para el ganador de cada competencia.  todos los socios de aepa recibirán un certificado de participación.
#
# la competencia de cotejo requerirá las correcciones de un documento en español con errores ortográficos, tipográficos, gramaticales y de formato.  el ejercicio será seleccionado y evaluado por la profa. milagros castro, consejera de la asociación.  las correcciones serán realizadas con los símbolos de corrección.
#
# bonito día
#
# Predicted labels: ['Spanish', 'Everyone']
#
# Actual labels: ['Competition', 'Spanish', 'Business', 'Everyone']
#
# ¡¡saludos colegiales!!
#
# ven, anímate y pasa por nuestras oficinas del complejo natatorio para matricularte.
#
# ¿dónde? - complejo natatorio rum (salón comedor 117)
# ¿cuándo? – lunes y miércoles
# 	4:30pm-5:30pm intermedio
# 	5:30pm-6:30pm básico
#      - lunes a viernes
# 	6:30pm- 7:30pm team maracas (avanzado)
# ¿costo? -  $50 por 10 clases
# método de pago: ath, visa o mastercard
# instrucciones:
# 1- llenar relevo de responsabilidad.
# 2- certificado médico que indique que puede realizar este ejercicio.
# 3- traer agua o bebidas hidratantes
# 4-  una toalla (opcional)
#
# instructora: soraya valentín
#
# dudas o cualquier otra información, comunícate con nosotros al 787-832-4040; ext. 5777 y 6257 o escríbenos a natatorio@uprm.edu
#
# Predicted labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# anuncian inicio de venta de boletos para hamilton
#
# el productor jeffrey seller y lin-manuel miranda anunciaron hoy que los boletos individuales para hamilton saldrán a la venta al público el sábado 10 de noviembre de 2018 para las funciones del 8 al 27 de enero de 2019 en puerto rico.  miranda recreará su interpretación de alexander hamilton de manera exclusiva para esta temporada de tres semanas en el teatro de la universidad de puerto rico, recinto de río piedras.
#
# las entradas estarán disponibles desde las 9:00 am en persona en la boletería del teatro de la universidad de puerto rico, recinto de río piedras, en todos los centros ticketpop de puerto rico y por internet en www.ticketpop.com.
#
# hay un límite máximo de compra de cuatro (4) boletos por cuenta para las funciones durante estas tres semanas de hamilton en la isla caribeña.  los precios de las entradas oscilarán entre $99.00 y $338.40, incluyendo los cargos de ticketpop y el impuesto de ventas y uso (ivu) local. las entradas no estarán disponibles para la compra por teléfono el sábado 10 de noviembre.
#
# cualquiera y todas las transacciones que se detecten como compras de “bot” (de robots de computadoras), clientes que creen cuentas duplicadas para comprar más de cuatro (4) entradas, o cualquier acción que indique una compra en exceso del límite de cuatro (4) boletos podrán ser canceladas sin ningún tipo de consideración.  las entradas sólo se entregarán al propietario de la tarjeta de crédito o débito utilizada para comprarlas. los boletos no se entregarán si los nombres que figuran en la identificación y en la tarjeta de débito/crédito no coinciden con el nombre que figura en la orden de compra, o si la identificación no es de la persona que recoge los boletos. las entradas no pueden ser recogidas por terceros. los boletos pueden ser recogidos sólamente dos horas antes de la hora de cada función.  por favor visite https://hamiltonmusical.com/puerto-rico/tickets para más información.
#
# jeffrey seller dijo que, "puede ser una tentación intentar conseguir boletos de cualquier manera posible. hay muchos portales cibernéticos y personas que estarán vendiendo boletos a sobreprecio y, en algunos casos, fraudulentos.  para los mejores asientos, los mejores precios y para eliminar el riesgo de boletos falsos, ticketpop, el fondo flamboyán para las artes, la compañía de turismo de puerto rico y otros patrocinadores corporativos son las únicas fuentes oficiales para comprar entradas para hamilton en puerto rico".
#
# Predicted labels: ['Social Events', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Social Events', 'Spanish', 'All Majors', 'Everyone']
#
# comunidad universitaria!
#
# el complejo natatorio, tenis y racquetball se complace en presentar su nuevo programa junior lifeguard.
#
# junior lifeguard course:
#
# para la edad de 11-14años
# costo de $125
#
# pre-requisitos (pre-prueba):
# nadar pecho y libre
# mantenerse flotando durante 1 minuto
# sumergirse en el agua
# *de no pasar la pre-prueba no podrá participar del programa*
#
# propósito del programa: el estudiante aprenderá acerca de las destrezas y habilidades a ejecutar durante una emergencia acuática. también aprenderá  conceptos como cpr/atragantamiento/dea/primeros auxilios.
#
# esta formación no equivale a una licencia de salvavidas. para obtener la licencia de salvavidas el participante debe tener 15 años cumplidos. en cambio, el estudiante en el programa junior lifeguard adquirirá todos los conocimientos necesarios para responder a una emergencia. al final del curso recibirá una certificación del programa junior lifeguard.
#
# para más información: natatorio@uprm.edu
# llamar al 7878324040ext. 5777
#
#
# la certificación es por la cruz roja americana
#
# Predicted labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# departamento de humanidades
# recinto universitario de mayagüez
#
# convocatoria
# tablón efímero de expresión artística (teea)
#
#
# en enero de 1969 comienzan formalmente los programas académicos del departamento de humanidades en el recinto universitario de mayagüez de la universidad de puerto rico.  con motivo de tan importante acontecimiento, el departamento de humanidades celebrará su jubileo 50 con una serie de actividades, entre las cuales está el tablón efímero de expresión artística (teea).
#
# el comité de aniversario del humanidades del recinto universitario de mayagüez convocan al estudiantado del departamento de humanidades a someter propuestas conducentes a la segunda edición. la teea, un tablón, de 4’ de alto y 24’ de largo, ubicado en el llamado espacio klumb, en el cual los estudiantes de artes plásticas de nuestro departamento presentarán a la comunidad universitaria una muestra temporal de sus habilidades y talentos.
#
# normas de participación:
#
# 1.	podrán participar estudiantes del recinto universitario de mayagüez que hayan aprobado o estén matriculados en al menos un taller de arte en el departamento de humanidades.
# 2.	podrán participar estudiantes que no hayan tomado cursos en nuestro departamento siempre y cuando se asocien a un estudiante que sí hayan aprobado o estén matriculado en algún taller de arte en nuestro departamento.
# 3.	la participación puede ser individual o como colectivo, tomando en cuenta que todos los integrantes deben ser estudiantes regulares en el recinto universitario de mayagüez. se entiende como colectivo dos o más personas, de las cuales al menos una debe haber aprobado o estar matriculado en un taller de arte de nuestro departamento.
# 4.	solamente se podrá entregar una propuesta por individuo o colectivo, no bajo ambas. entiéndase, como individuo o como colectivo.
#
# formato de la propuesta:
#
# 1.	la propuesta se entregará a la dirección electrónica 50tahuma@gmail.com, en o antes del lunes 5 de noviembre del 2018.
# 2.	la propuesta debe incluir lo siguiente:
# a.	categoría: individual o colectiva.
# b.	nombre(s), número de estudiante(s) y prueba de haber aprobado o estar matriculado en un taller de arte de nuestro departamento.
# c.	título y breve descripción del proyecto, incluyendo el medio a usarse.
# d.	boceto a color y a escala de la propuesta.
# 3.	se aceptará cualquier medio artístico – sin embargo en esta segunda edición solicitamos que las propuestas presenten alternativas novedosas que incorporen materiales, técnicas y conceptos más allá de lo tradicional.
# 4.	las propuestas deben tomar en cuenta que el tablón mide 4’ de alto y 24’ de largo.
#
# procedimiento:
#
# 1.	las propuestas que no cumplan con los requisitos del formato arriba indicado no serán evaluadas y quedan descalificadas.
# 2.	serán seleccionadas las mejores dos propuestas, independientemente si ambas son individuales o colectivas. cada propuesta seleccionada se realizará en una de las dos caras del tablón.
# 3.	los estudiantes seleccionados firmarán un documento de compromiso para tener listas las obras para el comienzo del nuevo semestre académico.
# 4.	los materiales y herramientas necesarias para la creación de las obras serán provistas por los proponentes.
# 5.	el montaje de la obra será responsabilidad exclusiva de los proponentes al igual que su desmontaje.
# 6.	si por alguna circunstancia alguna de las dos propuestas ganadoras no puede ejecutarse o no puede terminarse a tiempo, el comité podrá, sin perjuicio de los proponentes afectados, ejecutar las medidas que se entiendan necesarias para completar las obras y/o crear nuevas obras.
# 7.	los participantes firmarán un documento de relevo en el cual se comprometen a cumplir con el tiempo establecido de un semestre para la duración de su obra. luego del tiempo establecido la obra será borrada para las próximas propuestas escogidas. si los estudiantes se niegan a firmar el relevo, su propuesta será denegada.
#
#
# itinerario
#
# 1.	la fecha límite para entregar las propuestas es el 5 de noviembre de 2018.
# 2.	las propuestas serán evaluadas por un comité de aniversario del humanidades.
# 3.	la fecha cuando se anunciarán las propuestas ganadoras es el 20 de noviembre del 2018.
#
# Predicted labels: ['Competition', 'Spanish', 'Arts & Sciences', 'Everyone']
#
# Actual labels: ['Competition', 'Social Events', 'Spanish', 'All Majors', 'Everyone']
#
# ¡saludos colegiales!
#  ¡comienzan las clases de yoga!
#  ven, anímate y pasa por nuestras oficinas del complejo natatorio para matricularte
# ¿dónde? - complejo natatorio rum (2do nivel - oficina natatorio 206)
# ¿cuándo? – lunes, miércoles y viernes
# 	      5:00pm – 6:15pm
# ¿edad? - 15 años en adelante
# ¿costo? -  $50 por 10 clases
# 	     $25 por 5 clases
# método de pago: ath, visa o mastercard
# instrucciones:
# 1- llenar relevo de responsabilidad
# 2- certificado médico que indique que puede realizar este ejercicio
# 3-  mat de yoga
# 4-  bloques (x2)/ cinto (opcional)
# 5- traer agua o bebidas hidratantes
# 6- una toalla (opcional)
# dudas o cualquier otra información, comunícate con nosotros al 787-832-4040; ext. 5777 y 6257 o escríbenos a natatorio@uprm.edu
#  link
# Predicted labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Class', 'Spanish', 'All Majors', 'Everyone']
#
# senado académico 30 de octubre de 2018.
#
#  link
# Predicted labels: ['University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# ¡¡saludos colegiales y comunidad en general!!
#
# ¡¡nos place informarle que el complejo natatorio, tenis y racquetball ofrecer clases de zumba totalmente gratis!!
#
# días: lunes a jueves
# hora: 6:30pm a 7:15pm
# lugar: entrada a la boletería principal del complejo natatorio (frente al edificio de administración de empresas).
#
# para más información, comuníquese con nosotros al correo electrónico: natatorio@uprm.edu o al teléfono (787)832-4040 ext. 5777.
#
# Predicted labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Class', 'Social Events', 'Spanish', 'All Majors', 'Everyone']
#
# ¡saludos colegiales!
#
# ¡nos place informarle que el complejo natatorio, tenis y racquetball ofrecerá por primera vez clases de hip-hop!
# ven, anímate y pasa por nuestras oficinas del complejo natatorio para matricularte.
#
# ¿dónde? - complejo natatorio rum (salón comedor 117)
# ¿cuándo? – martes y jueves
# ¿hora? -  5:30pm-6:30pm
# ¿costo? -  $50 por 10 clases
# método de pago: ath, visa o mastercard
#
# instrucciones:
# 1- llenar relevo de responsabilidad.
# 2- certificado médico que indique que puede realizar este ejercicio.
# 3- traer agua o bebidas hidratantes
#
# instructora: fabiola rodríguez
#
# dudas o cualquier otra información, comunícate con nosotros al 787-832-4040; ext. 5777 y 6257 o escríbenos a natatorio@uprm.edu
#  link
# Predicted labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# colegial!!!  sabías que existen deportes adaptados?  los deportes adaptados son creados para que las personas con diversidad funcional puedan beneficiarse de la actividad física, la competencia y la socialización que provee el deporte.
# el curso edfi 4017, deportes adaptados, te invita a conocer más sobre estos deportes!  se ofrecerá una charla este próximo jueves 1ro de noviembre en el salón cm-201 a la hora universal.  este taller te preparará para participar en nuestro día de juegos el viernes, 2 de noviembre a partir de las 9:30am.
# únete a nosotros en un rato de diversión y aprendizaje!!!  es completamente gratuito!!!!!
# te esperamos!!!!!
#
# Predicted labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# ¡saludos colegiales!
# ven, anímate y pasa por nuestras oficinas para matricularte.
#
# ¿para quién? -niños desde 3 años hasta adultos.
#
# ¿dónde? - complejo tenis rum
#
# ¿cuándo?
#  lunes, miércoles y viernes:
#         - clases privadas por acuerdo; para más información comunicate con nosotros.
#
# martes y jueves:
#         - 6:00pm – 7:30pm básico e intermedio niños
# 	- 7:30pm– 9:00pm básico e intermedio adultos
#
# ¿costo?  -comunidad en general: $100.00
#                 -exalumnos o empleados: $90.00
#                 -estudiantes del rum: $60.00
#
# * 8 clases de 1.5 horas*
#
# método de pago: ath, visa o mastercard
# instrucciones:
# 1- llenar relevo de responsabilidad.
# dudas o cualquier otra información, comunícate con nosotros al 787-832-4040; ext. 5777 y 6257 o escríbenos a natatorio@uprm.edu
#  link
# Predicted labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Class', 'Spanish', 'All Majors', 'Everyone']
#
# ¡saludos, colegiales y comunidad en general!
#
# ven, anímate y pasa por nuestras oficinas del complejo natatorio para matricularte.
#
# para niños y jóvenes desde los 7 años hasta los 18
#
# costo (mensual):
# $80 (primer hijo)
# $60 (segundo hijo en adelante)
#
#
# horario:
# 4:30 pm a 7:00 pm (todos los días)
# entrenadora: brenda colon
# método de pago: ath, visa o mastercard
# deberá presentar:
# certificado médico (documento que provea el médico, no hay formato en particular)
# exalumnos: copia del diploma.
#
#
# dudas o cualquier otra información, comunícate con nosotros al 787-832-4040; ext. 5777 y 6257 o escríbenos a natatorio@uprm.edu
#
# Predicted labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Sports & Fitness', 'Class', 'Spanish', 'All Majors', 'Everyone']
#
# como parte de la programación educativa de la exposición agustín stahl: palmas, cactus y comestibles, musa le invita a la conferencia:
#
# etnobotánica boricua: árboles y matojos que sanan
# jueves, 15 de noviembre
# 6:00 pm
#
# conoce sobre nuestra medicina ancestral: un legado de los abuelos y las abuelas boricuas y centroamericanos. la autora y educadora etnobotánica maría benedetti nos ofrecerá una conferencia ilustrada, informativa y amena sobre 15 plantas de importancia vital para la sustentabilidad y la salud del pueblo puertorriqueño. luego de la conferencia, benedetti servirá un sabroso caldo súper alimenticio con un yerbajo medicinal súper abundante pero poco apreciado.
#
# capacidad máxima de la sala 55 personas. para reservar su espacio:
# 1. llamar al 832-4040 ext. 5775
# 2. escribir a actividades.musa@uprm.edu o
# 3. completar el siguiente formulario https://goo.gl/forms/dvisujteovhsfkvz1.
#
# evento libre de costo.
#
# Predicted labels: ['Workshop', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Workshop', 'Spanish', 'All Majors', 'Everyone']
#
# somos la “financial management association” (fma) y tenemos el placer de invitarte a nuestro primer info session/reunión de socios del semestre. nuestra misión es desarrollar y promover el conocimiento financiero entre nuestros socios, para que puedan distinguirse entre sus pares a nivel académico y profesional.
#
# cuando: martes 30 de octubre
# dónde:  ae-302
# hora:   10:30 am – 12:00 pm
#
# pd: habrá pizza :)
#
# Predicted labels: ['Student Associations', 'Spanish', 'Business', 'Everyone']
#
# Actual labels: ['Student Associations', 'Spanish', 'Business', 'Everyone']
#
# ¿tienes examen de precálculo 1?
#
# en el centro de aprendizaje y éxito rumbo ex en celis-011 nos comprometemos con aportar en lo posible para que los estudiantes alcancen el mayor de los éxitos. el próximo domingo, 28 de octubre de 2018, ofreceremos repaso para precálculo 1 de 3:00pm a 7:00pm. ¿tienes dudas en esta materia? cuenta con nosotros para darte la mano.
#
# ¡seguimos juntos rumbo al éxito!
#
# servicios auspiciados por el proyecto título v: “pathways to success: rumbos para el éxito”.
#
# Predicted labels: ['Class', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Workshop', 'Class', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# r is the de facto standard for statistical analysis today. while it has been used by professional statisticians for a quarter century it has also become the preferred tool in many applied sciences. in this two part workshop i will give an introduction to r.
#
# part 1 will take place on tuesday november 6 at 10:30am in ch116. in this part i will discuss how to get started with r. how to carry out basic operations such as inputting data, how to pull interesting parts from a data set and so on.
#
# part 2 will take place on tuesday november 8 at 10:30am in ch 116. in this part i illustrate how to use r to carry out a number of data analyses using methods such as the t test, anova, correlation and regression.
#
# for further information email me at wolfgang.rolke@upr.edu
#
# dr. wolfgang rolke
# department of mathematical sciences
# university of puerto rico - mayaguez
#
# Predicted labels: ['Workshop', 'English', 'All Majors', 'Everyone']
#
# Actual labels: ['Workshop', 'English', 'All Majors', 'Everyone']
#
# el centro de aprendizaje y éxito rumbo ex ubicado en celis 011 estará abierto el domingo, 28 de octubre de 2018. contamos con servicio de préstamo de “tablets’’ y préstamo de libros; precálculo, cálculo, química y psicología. te ofrecemos un ambiente de sala de estudio de primera. este fin de semana estaremos ofreciendo servicio en el siguiente horario:
#
# centro de aprendizaje y éxito rumbo ex (celis 011)
# domingo, 28 de octubre de 2018- 11:00a.m. – 8:00p.m.
#
# ¡seguimos rumbo al éxito!
#
# te esperamos.
#
# servicios auspiciados por el proyecto título v: “pathways to success: rumbos para el éxito”.
#
# Predicted labels: ['University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# la biología sintética, la ingeniería genética y otros temas relacionados a estas disciplinas suelen ser algo controversiales. esto debido a la infinidad de aplicaciones que pueden surgir a raíz de investigaciones y proyectos en estas áreas de estudio. por tanto,el equipo de investigación igem rum, te invita a un taller tipo conversatorio con la dr. sara gavrell,phd y el dr. hector huyke,phd profesores del departamento de humanidades de nuestro recinto. este se estará llevando a cabo el martes, 30 de octubre en chardón- 320 durante la hora universal (10:30 am).
#
# *** es importante que todas las personas interesadas en participar hayan leído de ante mano la lectura que se encuentra en el siguiente enlace***
#
#  link para más información nos pueden contactar en: igemrum@gmail.com o como @igemrum en la redes sociales
#
# -team igem rum
#
# Predicted labels: ['Workshop', 'Spanish', 'Arts & Sciences', 'Everyone']
#
# Actual labels: ['Workshop', 'Spanish', 'Arts & Sciences', 'Everyone']
#
# ¿te interesa aprender sobre el desarrollo de la niñez y los factores sociales que le afectan? ¿te interesa aprender sobre como la violencia puede afectar el desarrollo cognitivo de una persona?
# el proyecto cultura de paz es un proyecto dirigido a hijxs de las mujeres participantes del proyecto siempre vivas, así como para estudiantes y profesionales de agencias públicas y privadas. ambos proyectos tienen la misión de detener el ciclo de la violencia de género y en las familias así como crear conciencia hacia una cultura de paz en nuestra sociedad.
# el proyecto cultura de paz te invita a un voluntariado social en el cual obtendrás un adiestramiento para trabajar directamente con menores. en este voluntariado aprenderás sobre la carta de derechos de la niñez y tendrás la oportunidad de colaborar con una comunidad que ha vivido o esta violencia.
# para más información, favor de contactar a la profa. ana nieves a su correo electrónico ana.nieves2@upr.edu. tambien se puede comunicar con la profa. luisa seijo al 787-390-3371 o a su correo electrónico luisa.seijo@upr.edu.   ¡gracias!
#
# Predicted labels: ['Social Events', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Social Events', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# 4ta edición semana de las ciencias económicas – conferencia: reflexiones y soluciones: puerto rico ante la gran depresión del siglo xxi. conferenciantes: personal docente departamento de economía. lugar: anfiteatro josefina torres torres en enfermería. día: martes, 30 de octubre de 2018. hora: 10:30 am – 12:00 pm. para más información, favor enviar un correo electrónico a jeffrey.valentin@upr.edu o llamar al (787) 832-4040 x-2314.
#
# Predicted labels: ['Conference', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Conference', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# jóvenes del colegio,
#
# se les invita a participar en la competencia de cálculo 2018 y competencia de pre-cálculo 2018 del colegio.
#
# este año, las competencias se llevarán a cabo el martes, 27 de noviembre de 9:00 am a 4:00 pm en el mezzanine de las canchas de tenis pedro "golo' laracuente y en el salón p-107 del natatorio del rum.
#
# la competencia consiste de un examen individual de 10 problemas en 90 minutos. la competencia de pre-cálculo está abierta a estudiantes de escuela superior y estudiantes universitarios de primer año. la  competencia de cálculo está abierta a todos los estudiantes.
#
# habrá merienda y almuerzo.
#
# les estoy enviando la agenda preliminar y el enlace al formulario de inscripción. solicito que llenen el formulario lo más pronto posible, en o antes del lunes 4 de noviembre.
#
# enlace al formulario de inscripcion:
#  link espero poder saludarles ese día,
# dr. freddie santiago hernández
# depto. de ciencias matemáticas
# coordinador de competencias
#
# dr. freddie santiago hernández
# depto. de ciencias matemáticas
# freddie.santiago1@upr.edu
# (787)340-0834
#
# Predicted labels: ['Competition', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Competition', 'Spanish', 'All Majors', 'Everyone']
#
# financial management association (fma) de la universidad de puerto rico – recinto de mayagüez, te invita a nuestro primer info session/reunión de socios del semestre. nuestra misión es desarrollar y promover el conocimiento financiero entre nuestros socios, para que puedan distinguirse entre sus pares a nivel académico y profesional.
#
# ¡anímate, se parte de la fma!
#
# ¿cuándo? martes 30 de octubre de 2018
# ¿dónde? ae-302
# ¿hora? 10:30 am – 12:00 md
#
# Predicted labels: ['Student Associations', 'Spanish', 'Business', 'Everyone']
#
# Actual labels: ['Workshop', 'Student Associations', 'Spanish', 'Business', 'Everyone']
#
# les exhorto a que verifiquen en su cuenta en mi portal, através de un icono localizado dentro del "folder" services for students, las respuestas a las solicitudes de traslado interno, secuencia curricular y concentración menor para el segundo semestre 2018-2019. según recibamos las mismas estaremos actualizando la información.
#
# Predicted labels: ['University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# taller para solicitar internados o empleo con el natural resource conservation service (nrcs) a través de usajobs
#
# el próximo 29 de noviembre de 2018, durante la hora universal (10:30am-12:00pm), salón ap-101 se estará ofreciendo un taller sobre solicitud a posiciones con nrcs a través de la plataforma usajobs. los espacios son limitados, se les recomienda llenar el registro electrónico lo antes posible para separar su cupo, la fecha limite para registro es en o antes del 10 de noviembre de 2018.
#
# requisitos:
# tener o abrir cuenta en usajobs y resume en vigente en la misma (upload o built-in).
#
# registro electrónico para el taller:
#  link para más información, puede contactar a:
# yaniria sánchez de león, ph.d.
# yaniria.sanchez@upr.edu
#
# damuel morales barreto
# damuel.morales@upr.edu
#
# this material is based upon work supported by the natural resourse conservation service us department of agriculture, under number 69-3a75-16-914.
#
# Predicted labels: ['Internship or Job Application', 'Workshop', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Internship or Job Application', 'Workshop', 'Spanish', 'All Majors', 'Everyone']
#
# el programa de orientación y recursos para la transición e inmersión colegial (pórtico) le invita a la semana de desarrollo profesional a realizarse del 29 de octubre al 1 de noviembre de 2018.
#
#
# programa de actividades
#
# lunes, 29 de octubre de 2018
# mesa informativa: ayuda para tu éxito académico
# 9:00 a.m. a 12:00 p.m.
# en el centro de aprendizaje y éxito rumbo ex (celis 011)
#
# martes, 30 de octubre de 2018
# conferencia: "cuando sea grande quiero ser..." ¿cómo saberlo?10:30a a 11:45 a.m.
# lugar: anfiteatro ramón figueroa chapel
#
# miércoles, 31 de octubre de 2018
# un café por el éxito: conversatorio con ex-alumnos exitosos
# 3:30 a 5:00 p.m.
# lugar: centro de aprendizaje y éxito rumbo ex (celis 011)
#
# jueves, 1 de noviembre de 2018
# panel - historias de éxito: experiencias de internado, intercambio y coop
# 10:30 a 11:45 a.m.
# en el anfiteatro ramón figueroa chapel
#
# ¡gran cierre! fiesta pórtico colegial
# 6:30 a 10:00 p.m. centro de estudiantes - tercer piso
# 7:00 p.m. clases de salsa
# 8:30 p.m. salsa night
# habra artesanías y kiosko de comida
#
# auspiciado por - proyecto título v: “pathways to success: rumbos para el éxito”
#
# Predicted labels: ['Conference', 'Social Events', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Workshop', 'Conference', 'Social Events', 'Spanish', 'All Majors', 'Everyone']
#
# a la comunidad universitaria:
#
# informamos que la actividad de come colegial pautada para hoy, 25 de octubre, ha sido cancelada por razones fuera del control de la asociación.
#
# próximamente se anunciará por las redes sociales la nueva fecha.
#
# Predicted labels: ['Social Events', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Social Events', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# el programa de ciencia y tecnología de alimentos en colaboración con la división de educación continua (decep) estará ofreciendo el taller:
#
# análisis de peligros y puntos críticos de control (haccp) los días 31 de octubre, 1 y 2 de noviembre de 2018
#
# descripción
# haccp es una metodología para evaluar el riesgo que conllevan los diferentes peligros biológicos, químicos y físicos presentes en un proceso de elaboración de alimentos. el taller explica detenidamente los cinco pasos y siete principios y permite al participante la oportunidad de elaborar un plan haccp para una situación hipotética. el ejercicio y discusión del mismo provee experiencia práctica en la aplicación de la herramienta. el taller cumple con los requisitos de capacitación requeridos por las agencias regulatorias fda y usda. se espera que los participantes hayan tomado un taller de buenas prácticas de manufactura, o tengan conocimiento de dicha regulación.
#
# promoción: https://bit.ly/2o7kxj4
#
# estudiantes del rum con identificación pagan: $360 para matrícula deben pasar a sánchez hidalgo 401.
#
# precio general: $425
#
# para más información favor pasar por el edificio efraín sánchez hidalgo, oficina 401 ó comunicarse al 787-832-4040 exts. 3054 ó 3058.
#
# ¡búscanos en las redes sociales y danos like nos encuentras como decep uprm en facebook, twitter y linkedin!
#
# ¡te esperamos!
#
# Predicted labels: ['Workshop', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Workshop', 'Spanish', 'All Majors', 'Everyone']
#
# ven a orientarte sobre los viajes que organiza la upr- carolina para este verano 2019:
#
# viaje estudios a europa 2019
#
# orientación para estudiantes de la upr mayagüez
# sábado, 3 de noviembre de 2018
# 10:00 am
# salón r115 ciencias naturales en la upr aguadilla
#
#
#
# viaje gastronómico 2019: península ibérica
#
# orientación para estudiantes de la upr mayagüez
# sábado, 3 de noviembre de 2018
# 1:00 pm
# salón r115 ciencias naturales en la upr aguadilla
#
#
# para más información: (787)752-4575
# (787)257-0000 extensiones 3392, 4705, 4490
# alan.rodriguez1@upr.edu/perlie.adorno@upr.edu
#
# Predicted labels: ['Other', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Other', 'Spanish', 'All Majors', 'Everyone']
#
# applications for the frederick douglass global fellowship will now close on february 14, 2019!
#
#
# applications are open for the 2018-2019 cohort, who will travel to rio de janeiro, brazil in summer 2019 for a credit-earning study abroad program on intercultural communication and leadership. scholarship funds will cover 100 percent of all program fees and travel costs for a cohort of 10 students from minority serving institutions (msis).
#
# the frederick douglas global fellowship (fdgf) program is a product of a partnership between ciee and the penn center for minority serving institutions (cmsi) established to create an opportunity for outstanding, underrepresented students to participate in an intense leadership and intercultural study abroad experience. this program was designed to break down the barriers of cost, curriculum, and culture to make study abroad accessible to students from msis.
#
# selected frederick douglass global fellows are meritorious individuals who demonstrate high academic achievement, possess exemplary communication skills, display the hallmarks of self-determination, exhibit characteristics of bold leadership, and have a history of service to others.
#
# in the spirit of one of america’s most powerful intellectuals, communicators, and scholars, frederick douglass global fellows will commit to sharing their experiences and intercultural growth with peers and classmates before, during, and after the fellowship.
#
# for more information:
#  link
# Predicted labels: ['Scholarships & Fellowship', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Scholarships & Fellowship', 'Spanish', 'All Majors', 'Everyone']
#
# 24 de octubre de 2018
#
#
# a toda la comunidad universitaria
#
#
# el colegio de ingenieros y agrimensores de puerto rico (ciapr) se ha dado a la tarea de levantar el fondo económico conocido como fondo de becas del ciapr. este fondo tiene como propósito estimular el estudio de las ciencias de la ingeniería y la agrimensura en puerto rico, sirve para apoyar a sufragar los gastos de estudio de aquellos que habrán de convertirse en los ingenieros y agrimensores de nuestro país, al igual que para ayudar a aquellos que desean especializarse en estas materias por medio de un post-grado. el mismo está destinado para proveer becas en las disciplinas de: agrimensura, ingeniería civil, de computadoras, eléctrica, industrial, mecánica, ambiental y química.
#
# pueden conseguir el reglamento y el formulario de solicitud en la siguiente dirección: www.ciapr.org, bajo la pestaña de "estudiantes", luego "becas", y finalmente pulse la palabra "aqui", entonces aparecerá el reglamento de becas en formato pdf
#
# el estudiante debe completar la solicitud, acompañar los documentos que se le solicitan, y someterla por correo electrónico, entregarla a la mano, o enviarla por correo regular. las direcciones aparecen detalladas en el reglamento.
#
# fecha limite para solicitar una beca: el ciapr debe recibir las solicitudes, en o antes del 31 de mayo de cada año.
#
# para mas información ver presione aquí:   http://uprm.edu/cms/index.php?a=file&fid=17486
#
# Predicted labels: ['Scholarships & Fellowship', 'Spanish', 'Engineering', 'Everyone']
#
# Actual labels: ['Scholarships & Fellowship', 'Spanish', 'Engineering', 'Everyone']
#
# musa
# le invita a la programación educativa
# en torno a la exposición
# agustín stahl: palmas, cactus y comestibles
#
#
# las cactáceas de p.r. y su conservación
# jueves, 25 de octubre
# 5:20 – 6:30 pm
#
# acompañe al botánico omar monsegur en una charla dirigida a conocer la diversidad y endemismo de las cactáceas de puerto rico e islas vírgenes. se discutirá el estatus de nuestras especies, su distribución geográfica, la importancia ecológica y los esfuerzos de conservación, utilizando como ejemplo harrisia portoricensis y leptocereus grantianus. entrada libre de costo.
#
# Predicted labels: ['Conference', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Conference', 'Spanish', 'All Majors', 'Everyone']
#
# ¿estas atrás en descubrir los “spots” mas bonitos de la isla?
#
# esta excursión es para ti… ¡ven y descubre isabela con cvs!
#
#
# la primera parte de excursión se compone de una caminata pasiva por las veredas del merendero de guajataca. un excelente lugar para tomar fotos, comerse un snack y relajarse mientras disfruta del paisaje panorámico de la playa y el túnel de guajataca. además, visitaremos el mirador de isabela para una vista espectacular de la costa noroeste. ¡también conocido como el mirador del cielo!
# la segunda parte de la eco-aventura seria llegar a un local reservado frente de la playa desde donde tendremos una caminata costera hasta llegar a la poza las golondrinas, una de las playas favoritas de los locales. se concluye el día con un almuerzo incluido con vistas a la playa. sera un medio día de excursión y compartir excelente para aquellos aventureros que quieren descubrir más de nuestra isla.
#
# día: domingo, 28 de octubre
# lugar de encuentro: estacionamiento área blanca, frente el gimnasio espada
# hora de encuentro: 8:00 a.m.
# hora de salida: 8:30 a.m.
# transportación: carpooling (favor de indicar si necesita o puede ofrecer el mismo)
#
# registro del evento y más información se encuentra en el siguiente enlace: http://www.uprm.edu/portada/eventosverdes/index.php?a=ev&id=578
#
# pueden estar pendiente y disfrutar de nuestros próximos talleres, excursiones y eventos especiales de campus verde students y nuestras asociaciones aliadas en nuestra página de eventos verdes:  http://www.uprm.edu/portada/eventosverdes/index.php
#
#
# campus verde students-uprm
# edif. sánchez hidalgo, oficina sh-106.
# proyecto casa ecosolar - cid
# tel. (787) 832-4040 exts. 5831, 6407
# web page: http://campusverde.uprm.edu
#
# Predicted labels: ['Social Events', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Social Events', 'Spanish', 'All Majors', 'Everyone']
#
# fecha: 25 de octubre de 2018
# lugar: salón sh-102 (edificio sánchez hidalgo)
# horario: 10:30 am a 12:00 m (hora universal)
# tendremos entremeses para los participantes.
# notas importantes:
#
# 1) para asistir, favor llenar el "google form": https://goo.gl/oys6mf en o antes de las 11:59 pm de esta noche.
#
# 2) las personas ya inscritas, favor acceder el siguiente formulario de confirmación hoy en o antes de medianoche: https://goo.gl/sebsge.
#
# 3) es altamente recomendable los asistentes lleven su "laptop" para que practiquen la instalación y configuración de linux. tenemos muy pocas computadoras a nuestra disposición para prestar y el taller no será en un centro de cómputos.
#
# auspicia: arelec (asociación pro reciclaje de electrónicos) de uprm.
# invitan:
#      a) departamento de ciencia e ingeniería de computación
#      b) departamento de ingeniería eléctrica y computadora
#
# Predicted labels: ['Workshop', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Workshop', 'Spanish', 'All Majors', 'Everyone']
#
# take back day - devolución de medicamentos
# sábado, 27 de octubre de 2018
# 10:00 am - 2:00 pm.
# vé localidades cerca de ti.
#  link *devuelve los medicamentos expirados o que ya no utilices.*
# *no los botes a la basura ni al inodoro.*
# *evita contaminar el ambiente.*
#
# iniciativa de https://takebackday.dea.gov/
# con el apoyo de campus verde - uprm.
# campusverde@uprm.edu
#  link
# Predicted labels: ['Other', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Other', 'Spanish', 'All Majors', 'Everyone']
#
# take back day - devolución de medicamentos
# sábado, 27 de octubre de 2018
# 10:00 am - 2:00 pm.
# vé localidades cerca de ti.
#  link *devuelve los medicamentos expirados o que ya no utilices.*
# *no los botes a la basura ni al inodoro.*
# *evita contaminar el ambiente.*
#
# iniciativa de https://takebackday.dea.gov/
# con el apoyo de campus verde - uprm.
# campusverde@uprm.edu
#  link
# Predicted labels: ['Other', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Other', 'Spanish', 'All Majors', 'Everyone']
#
# ¿deseas ser parte de proyectos innovadores y revolucionarios en un ‘startup'?  ¿quieres trabajar en un ambiente innovador con los mejores emprendedores en puerto rico? ¿estás buscando un internado o empleo full time?
#
# de ser así, ¡no te pierdas la tercera feria de empleo de startups en puerto rico!
#
# ¿cuando será? viernes, 2 de noviembre del 2018
# ¿donde? mezzanine (sujeto a cambios)
#
# registrate gratis aquí: http://bit.ly/startupfair2018
#
# cosas que deben saber:
#
# algunos startups buscan voluntariado, pero la gran mayoría ofrecen internados y trabajos full-time pagos.
# hay oportunidades de internado para todas las concentraciones y no necesitan experiencia previa. solo muchas ganas de trabajar en temas innovadores.
# es altamente recomendado llevar al menos 10 resumes impresos.
# hay algunas oportunidades para trabajar remoto.
#
# para más información contactanos en:
# felipe.alfonzo@upr.edu
# ideaplatform@uprm.edu
# (787)-328-9152
#  link ¡no te lo pierdas!
#
# Predicted labels: ['Internship or Job Application', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Internship or Job Application', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# la unidad de educación continua y servicios a negocios (educon) les complace en invitarles a nuestro segundo pop up event para empresarios colegiales. dicho evento tiene como propósito primordial proveerle a los pequeños y medianos comerciantes la oportunidad de exponer sus productos/servicios y marca. de igual forma, el mismo se utiliza como una herramienta a estudiantes universitarios, asociaciones estudiantiles, alumnos recién graduados y empleados para fomentar su deseo por el mercado local.
#
# pueden participar los negocios especializados en:
#
# •artesanías
#
# •prendas
#
# •ropa
#
# •zapatos
#
# •accesorios
#
# •agronomía
#
# •comida previamente empacada
#
# el evento se llevará acabo el martes, 13 de noviembre de 2018 9:30a.m. a 1:30 p.m., en el lobby del edificio de administración de empresas (adem).
#
#
# la actividad requiere una aportación por participante de $10.00 para reservar su espacio y no habrá devolución de dinero, una vez se realice el pago.si estas interesado te puedes comunicar con nosotros a educon.adem@uprm.edu en o antes del 8 de noviembre de 2018.
#
# *requisitos que cada negocio debe tener:
#
# •negocios
#
# oregistro de comerciante
#
# •negocios de comida
#
# ocumplir con los requisitos del departamento de salud
#
# incluye una mesa por cada participante, y deberá entregar el formulario de participación y realizar el pago en el siguiente enlace:http://enterprise.uprm.edu/pagos/index.php?reca=25
#
#
# espacios limitados, ven y aprovecha esta gran oportunidad.
#
# *no se devolverá dinero, una vez se realice el pago.
#
# Predicted labels: ['Social Events', 'University Announcement', 'Spanish', 'Business', 'All Majors', 'Everyone']
#
# Actual labels: ['Social Events', 'Student Associations', 'Spanish', 'Business', 'All Majors', 'Everyone']
#
# hoy es la primera reunión de la nueva asociación estudiantil de agricultores cooperativistas (aeac).
#
# ...
#
# --- estudiante sub-graduado o graduado
# ---matriculado en su último semestre para graduarse
# ---haber radicado fafsa 2018-19 y salir inelegible
# ---no estar recibiendo ningún tipo de ayuda económica, ni ayudantía
# ---matriculado a tiempo completo (estudiante regular)
# ---ciudadano americano o residente permanente
# ---con 3.00 o más de promedio general
# ---cualquier facultad
# ---no estar en plan coop o internado
#
# documentos a entregar:
#
# --- presentar evidencia de solicitud de graduación
# ---ensayo no más de 2 páginas sobre sus necesidades económicas yt
#         metas profesionales.
# ---habrá entrevista de ser necesario
#
#
# fecha límite , miércoles 30 de mayo de 2018
#                         sra. lourdes i. matos, oficial asistencia económica
#                         departamento de asistencia económica
#                         l-v  8:00-11:30am  1:00-3:00 pm
#
# si no cumple con todos los requisitos favor no solicitar.
#
# Predicted labels: ['Scholarships & Fellowship', 'University Announcement', 'Spanish', 'Engineering', 'Undergraduate Student']
#
# Actual labels: ['Scholarships & Fellowship', 'Student Associations', 'Spanish', 'All Majors', 'All Students']
#
# saludos cordiales.
#
# el programa sea grant de la universidad de puerto rico te invita a las siguientes actividades durante el mes de abril de 2018. a continuación, compartimos información sobre cada una de ellas y los enlaces en los que hemos compartido la promoción y los detalles.
#
# sábado, 7 de abril de 2018, 9:00 a.m. - limpieza de playa en la reserva marina tres palmas en rincón ¡aún estás a tiempo para acompañarnos!
#  link 12 y 13 de abril de 2018, upr - mayagüez. edificio de ingeniería civil, laboratorio cairel - taller de gis para profesionales en recursos costeros
#  link domingo, 22 de abril de 2018 - festival de la villa pesquera de la playa de ponce
#  link
# Predicted labels: ['Spanish', 'All Majors', 'All Students', 'Everyone']
#
# Actual labels: ['Volunteer', 'Workshop', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# atención estudiantes graduados del recinto universitario de mayagüez:
#
# el graduate research and innovation center (gric) ofrece servicios gratuitos de asesoría y apoyo en proyectos de redacción académica en inglés para todas y todos los estudiantes graduados del recinto.
#
# nuestros graduate writing facilitators (gwfs) son estudiantes graduados del rum que han sido capacitados y están disponibles para ayudarte a bosquejar, revisar, editar y pulir tus trabajos académicos en inglés (desde borradores preliminares, informes y ensayos/”papers” requeridos para cursos hasta propuestas de tesis/disertación, capítulos de tesis/disertación, presentaciones orales, afiches, publicaciones, etc.).
#
# agenda tu cita aquí: http://libguides.uprm.edu/gric/gwf
#
# será un placer servirte y colaborar contigo en el cumplimiento de tus metas académicas.
#
# cordialmente,
# graduate writing facilitators
# graduate research and innovation center (gric)
# upr-recinto universitario de mayagüez
#  link  link
# Predicted labels: ['Student Associations', 'University Announcement', 'Spanish', 'All Majors', 'Graduate Student']
#
# Actual labels: ['Student Associations', 'Other', 'Spanish', 'All Majors', 'Graduate Student']
#
# machine learning in biomedical science
# dr. abiel roche-lima
# center for collaborative research in health disparities (ccrhd),
# medical science campus, university of puerto rico.
#
# date: tuesday, april 17, 2018
# time: 10:30am-12:00pm
# place: fisica-b
#
# abstract:
# machine learning is an area in computer science, which refers to analytical algorithms that iteratively learn from data, allowing computers to find hidden insights without being explicitly programmed to do so.  biomedical informatics is the application of information technologies to the context of biomedicine. we define some biomedical informatics terms, as well as the basics of machine learning algorithms. then, we discuss about the needs of machine learning to integrate and interpret complex biomedical and healthcare data. we also show general applications of machine learning in biomedical science, such as personalized medicine and drug discovery.  finally, we examine the potential limitations and challenges of implementing machine learning in the context of health care and medicine.
#
# ******
#
# dr. roche&#8208;lima earned his phd in computer sciences from the university of manitoba, canada. he has broad background applying computer science to biological sciences.  in the recent years, he has focused his research on developing bioinformatics and biomedical software based on machine learning approaches. dr. roche-lima has led and participated in projects, responsible for the experimental designs and bioinformatics support for extracting quantitative results. he previously worked at bio-information technologies laboratory, canada, where participated in several bioinformatics research projects. recently, dr. roche&#8208;lima started working at the center for collaborative research in health disparities (ccrhd), medical science campus, university of puerto rico. he has established his lab (arl-lab http://rcmi.rcm.upr.edu/arlab), on the development of bioinformatics and health informatics applications using novel learning algorithms. currently, he is the director of the integrated informatics core, as part of the rcmi program, funded by nih.
#
# contact:
# dr. wilson rivera
# wilson.riveragallego@upr.edu
#
# Predicted labels: ['English', 'Engineering', 'Arts & Sciences', 'Undergraduate Student']
#
# Actual labels: ['Conference', 'English', 'Engineering', 'Everyone']
#
# la oficina de calidad de vida junto al international kapap mayaguez academy te invitan a participar de las primeras clases gratis de defensa personal.
#
# martes 3 de abril 2018
# hora universal (10:30 am)
# f-329
#
# Predicted labels: ['Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Class', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# saludos,
#
# si estas interesado en  mejorar tus destrezas en excel o aprender esos truquitos que te facilitan la vida para hacer los trabajos, este taller es para ti.
#
# información:
# día: martes, 3 de abril de 2018
# hora: hora universal
# lugar: edificio lucchetti, ingeniería mecánica (l-242 a y b)
# costo: $2.00 para no-miembros. miembros gratis.
#
# nota: deberá llevar su laptop con el programa instalado.
#
# ¡espacios limitados!
#
# favor de registrarse usando el siguiente enlace: https://goo.gl/forms/as0tiukurcgz1qmk2
#
# para más información, contactar a carlos sánchez a carlos.sanchez26@upr.edu
#
# Predicted labels: ['Workshop', 'Spanish', 'All Majors']
#
# Actual labels: ['Workshop', 'Spanish', 'All Majors', 'All Students']
#
# la división de educación continua y estudios profesionales del recinto universitario de mayagüez en colaboración con lasalle group estarán ofreciendo la certificación en lean six sigma green belt.
#
# precio regular: $1,600.00
#
# precio para estudiantes del rum: $650.00
#
# el mismo se ofrecerá los sábados, de 8:30am a 4:30pm., comenzando el 7 de abril de 2018.
#
# curso incluye material didáctico y examen para certificarse.
#
# *espacios limitados *
#
# ¡expande tus horizontes! y no dejes perder esta gran oportunidad.
#
# para más información pasar por el edificio efraín sánchez hidalgo, oficina 401 ó comunicarse al 787-832-4040 exts. 3054 ó 3058.
# Predicted labels: ['Class', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Class', 'University Announcement', 'Spanish', 'Engineering', 'All Students']
#
# buenas,
#
# lamentablemente el taller de excel ofrecido por asme mañana martes 3 de abril del 2018, ha sido cancelado por razones fuera de nuestro control. a nuevo aviso se les dejara saber.
#
# gracias y perdone las inconveniencias.
#
# Predicted labels: ['University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Workshop', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# el centro de recursos de patentes y marcas de la biblioteca general les invitan a la presentación
#
#
#
# conociendo sobre la propiedad intelectual
#
#
#
# jueves, 5 de abril de 2018
#
# edificio sanchez hidalgo salón 203
#
# 10:30am
#
#
#
# en esta oportunidad conocerás sobre los diferentes tipos de propiedad intelectual. las diversas protecciones que tienen los inventores, emprendedores, artistas e investigadores para proteger su propiedad intelectual y mucho más.
#
#
# esta actividad fue sometida a la evaluación de la oficina de ética gubernamental para ser contada como horas contacto para el presente bienio.
#
#
#
# contacto
#
# prof. gladys e. lópez
#
# gladys.lopez@upr.edu
#
# 787-832-4040 ext. 5775
#
# Predicted labels: ['University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Conference', 'Spanish', 'All Majors', 'Everyone']
#
# faltan 32 días para el evento por la vida y el equipo aura de la national society of professional engineers está buscando estudiantes comprometidos que quieran ser parte de nuestro team y deseen ayudar a esta noble causa que apoya a los pacientes con cáncer brindándole servicios como lo es el puerto rico hope lodge, “una casa fuera de casa” donde los pacientes de cáncer se hospedan mientras reciben su tratamiento y equipos como el nuestro hacen posible que esas personas reciban este y otros servicios completamente libre de costo. si quieres ser parte de nosotros llena el siguiente formulario: https://docs.google.com/forms/d/e/1faipqlsdg2yvtbyomfmszhvbliedwac3hml1c8e8jdpzudhbclyftjq/viewform?usp=sf_link
#
#
# para artículos acceda al siguiente link: https://docs.google.com/forms/d/e/1faipqlsddkr9lx3iorahi2b-wcby7dfapvcpu3paadkskplfb0yqkpw/viewform?usp=sf_link
# la camisa se usa todos los viernes y se podrá usar también el jueves 3 de mayo en una marcha que se estará realizando dentro del campus.
#
# Predicted labels: ['Volunteer', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Volunteer', 'University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# saludos colegiales,
#
# cover letters and networking workshop
# si deseas aprender cómo redactar un cover letter para tu portafolio profesional y/o aprender técnicas para fortalecer tus conexiones con profesores y compañías este taller es para ti.
# dia: jueves, 5 de abril de 2017
# lugar: b-348
# hora universal
# 2 puntos
# form:  https://tinyurl.com/coverletterandnetwork
#
# venta de camisas justas 2018
# tendremos a la venta dos estilos de camisa de justas. estas tendrán in costo de 10$.
# la fecha límite para ordenar las mismas es el 15 de abril. ath móvil es (787)481-7129.
# si pagan a través de ath móvil escriben estilo de camisa, color, size y nombre.
# por la compra tendrán 3 puntos
#
#  el form para ordenar camisas es el siguiente: https://tinyurl.com/justaslai2018
#
# cómo entrar en un programa de ph.d o m./d. ph.d
# la asociación estudiantil marc u*star los invita a participar de su taller (guía) de preparación para estrar a programas de ph.d . aquí recibirán consejos de como prepararse para los distintos exámenes, redacción de personal statement, resume, cv entre muchas otras cosas.
# dia: jueves, 19 de abril de 2018
# lugar: anfiteatro de bilogia (b-392)
# hora universal
#
# siempre a su disposición,
#
# alpha helix biomedical society board
#
# Predicted labels: ['Workshop', 'Student Associations', 'Spanish', 'All Students']
#
# Actual labels: ['Workshop', 'Sale', 'Student Associations', 'Spanish', 'All Majors', 'Undergraduate Student', 'Graduate Student']
#
# saludos colegiales,
#
# cover letters and networking workshop
# si deseas aprender cómo redactar un cover letter para tu portafolio profesional y/o aprender técnicas para fortalecer tus conexiones con profesores y compañías este taller es para ti.
# dia: jueves, 5 de abril de 2017
# lugar: b-348
# hora universal
# 2 puntos
# form:  https://tinyurl.com/coverletterandnetwork
#
# venta de camisas justas 2018
# tendremos a la venta dos estilos de camisa de justas. estas tendrán in costo de 10$.
# la fecha límite para ordenar las mismas es el 15 de abril. ath móvil es (787)481-7129.
# si pagan a través de ath móvil escriben estilo de camisa, color, size y nombre.
# por la compra tendrán 3 puntos
#
#  el form para ordenar camisas es el siguiente: https://tinyurl.com/justaslai2018
#
# cómo entrar en un programa de ph.d o m./d. ph.d
# la asociación estudiantil marc u*star los invita a participar de su taller (guía) de preparación para estrar a programas de ph.d . aquí recibirán consejos de como prepararse para los distintos exámenes, redacción de personal statement, resume, cv entre muchas otras cosas.
# dia: jueves, 19 de abril de 2018
# lugar: anfiteatro de bilogia (b-392)
# hora universal
#
# siempre a su disposición,
#
# alpha helix biomedical society board
#
# Predicted labels: ['Workshop', 'Student Associations', 'Spanish', 'All Students']
#
# Actual labels: ['Workshop', 'Sale', 'Student Associations', 'Spanish', 'All Majors', 'Everyone']
#
# por este medio les invitamos a la charla
# vivienda, resiliencia y sostenibilidad: experimentos locales
#
# registro y más info:
#  link este jueves, 5 de abril de 2018
# hora: 10:30 am - 12:00 m
# anfiteatro figueroa chapel
# arquitecto dr. fernando abruña,
# fundador del capítulo del caribe de us green building council
#
# (se solicitarán horas de etica gubernamental)
#
# Predicted labels: ['Conference', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Conference', 'Spanish', 'All Majors', 'Everyone']
#
# estudiantes de inme, inin y kine interesados en colaborar como estudiantes orientadores del dcsp en las actividades de bienvenida y curso univ deberán pasar por la oficina del director en el ce-501 desde el lunes 9 hasta el lunes 16 de abril. requisitos: ser estudiante de inme, inin o kine; cursar el segundo año en adelante y tener gpa de 3.00 o más. para más información puede llamar al (787) 832-4040 x 3526
#
# Predicted labels: ['University Announcement', 'Spanish', 'All Majors', 'Everyone']
#
# Actual labels: ['Student Associations', 'University Announcement', 'Spanish', 'Engineering', 'Undergraduate Student']
#
# greetings colegiales!
#
#
#
#
#
# the department of defense (dod) is the nation’s largest and oldest federal agency with over 700,000 civilian employees in all types of jobs and majors.
#
#
#
#
#
# if you are searching for internships, jobs or programs, the department of defense has them for you. all our opportunities are posted on our webpage www.usajobs.gov.
#
#
#
#
#
# to apply for any of our positions you must have a federal resume. a federal resume is more than two pages and it contains much more information than the resume requested by private companies. if you wish to obtain help preparing your federal resume, learning about the department of defense and/or learning how to properly navigate our webpage to apply for any of our opportunities, you can contact and schedule a meeting our star representative kritzalis m. fermín at kritzalis.fermin@upr.edu or at (571) 302-1353.
#
#
#
#
#
#
#
# best of luck and see you soon!
#
#
#
#
#
#
#
# kritzalis m. fermín pacheco
#
#
# star (student training and academic recruitment) representative
#
#
# defense civilian personnel advisory service (dcpas)
#
#
# email: kritzalis.fermin@upr.edu
#
#
# phone: (571) 302-1353 or (939) 299-5196
#
# office: ae - 132
#
# Predicted labels: ['English', 'Engineering', 'All Students']
#
# Actual labels: ['Internship or Job Application', 'English', 'All Majors', 'All Students']
#
# la división de educación continua y estudios profesionales del recinto universitario de mayagüez en colaboración con lasalle group estarán ofreciendo la certificación en lean six sigma yellow belt.
#
# precio regular: $975.00
#
# precio para estudiantes del rum: $350.00
#
# el mismo se ofrecerá los sábados, de 8:30am a 4:30pm., comenzando el 21 de abril de 2018.
#
# curso incluye material didáctico y examen para certificarse.
#
# *espacios limitados *
#
# ¡expande tus horizontes! y no dejes perder esta gran oportunidad.
#
# para más información pasar por el edificio efraín sánchez hidalgo, oficina 401 ó comunicarse al 787-832-4040 exts. 3054 ó 3058.
#
# Predicted labels: ['Class', 'Spanish', 'All Majors', 'Undergraduate Student', 'Graduate Student', 'All Students', 'Everyone']
#
# Actual labels: ['Class', 'University Announcement', 'Spanish', 'Engineering', 'Business', 'All Students']
